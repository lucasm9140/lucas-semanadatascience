# %%
import pandas as pd

url = "dataset/Games.csv"
pd.read_csv(url)
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
# guarda o dataframe(dataset)
dados = pd.read_csv(url, sep=",")
dados
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
# lendo os 5 primeiros
dados.head()
# Out:
#          Console                                        GameName  \
# 0             PC             Baldur's Gate 3 Early Access Review
# 1             NS  Control: Ultimate Edition Cloud Version Review
# 2  XONE, PC, PS4    Doom Eternal: The Ancient Gods Part 1 Review
# 3  XONE, PC, PS4                       Watch Dogs: Legion Review
# 4             PC                             Ring Of Pain Review
#
#          Review  Score
# 0  Early Access      6
# 1          Good      7
# 2          Good      7
# 3         Great      8
# 4         Great      8

# %%
# Atribuindo quantos dados quero trazer
dados.head(25)
# Out:
#               Console                                           GameName  \
# 0                  PC                Baldur's Gate 3 Early Access Review
# 1                  NS     Control: Ultimate Edition Cloud Version Review
# 2       XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3       XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                  PC                                Ring Of Pain Review
# 5                  NS                             Pikmin 3 Deluxe Review
# 6       PC, XONE, PS4                                 Ghostrunner Review
# 7              PC, NS                  Disc Room Review – Getting Buzzed
# 8           XONE, PS4                                      NHL 21 Review
# 9                  PC                                       Noita Review
# 10                 PC                            Amnesia: Rebirth Review
# 11            PC, PS4                 Genshin Impact Review – Direct Hit
# ...

# %%
# ultimos 5 dados
dados.tail()
# Out:
#       Console                                           GameName    Review  \
# 14796      PC                                     Doom II Review     Great
# 14797      PC  Dungeon Master II: The Legend of Skullkeep Review  Mediocre
# 14798      PC                                    Endorfun Review      Good
# 14799      PC                              FIFA Soccer 96 Review    Superb
# 14800      PC                               Full Throttle Review     Great
#
#        Score
# 14796      8
# 14797      5
# 14798      7
# 14799      9
# 14800      8

# %%
# atribuindo quantos quero trazer a partir do ultimo dado, decrescente
dados.tail(23)
# Out:
#       Console                                           GameName    Review  \
# 14778      PC                                    Catfight Review   Abysmal
# 14779      PC                                      Strife Review      Good
# 14780      PC                            Micro Machines 2 Review     Great
# 14781      PC                                       Quake Review    Superb
# 14782      PC                                      Rayman Review      Good
# 14783      PC                                      TekWar Review      Poor
# 14784      PC                    Terminator: Future Shock Review     Great
# 14785      PC                                    Shannara Review      Good
# 14786      PC                           Command & Conquer Review    Superb
# 14787      PC                                     The Dig Review      Poor
# 14788      PC                                 Dark Forces Review      Good
# ...
